# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_excel("../RawData/hilfeleistungen_kreisebene/22121-01-04-4.xlsx")
data
# Out:
#      Empfänger nach Geschlecht, Nationalität, Ort der\nLeistungserbringung, Altersgruppen - Stichtag 31.12. -\nregionale Tiefe: Kreise und krfr. Städte  \
# 0     Statistik d. Empf. v.lfd. Hilfe z. Lebensunter...
# 1                Stichtag\nKreise und kreisfreie Städte
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 4344                                      Einrichtungen
# 4345  Bremen (2012): nur Empfänger außerhalb von Ein...
# 4346  © Statistische Ämter des Bundes und der Länder...
# 4347  Dieses Werk ist lizenziert unter der Datenlize...
# 4348  - Namensnennung - Version 2.0. | Stand: 14.07....
#
#      Unnamed: 1                        Unnamed: 2  \
# 0           NaN                               NaN
# 1           NaN  Empfänger(innen) von Sozialhilfe
# 2           NaN                               NaN
# 3           NaN                               NaN
# 4           NaN                            Anzahl
# ...         ...                               ...
# 4344        NaN                               NaN
# 4345        NaN                               NaN
# 4346        NaN                               NaN
# 4347        NaN                               NaN
# 4348        NaN                               NaN
#
#                             Unnamed: 3        Unnamed: 4  \
# 0                                  NaN               NaN
# 1     Empfänger(innen) von Sozialhilfe               NaN
# 2                             weiblich  Ausländer(innen)
# 3                                  NaN               NaN
# 4                               Anzahl            Anzahl
# ...                                ...               ...
# 4344                               NaN               NaN
# 4345                               NaN               NaN
# 4346                               NaN               NaN
# 4347                               NaN               NaN
# 4348                               NaN               NaN
#
#                        Unnamed: 5  \
# 0                             NaN
# 1                             NaN
# 2     außerhalb von Einrichtungen
# 3                             NaN
# 4                          Anzahl
# ...                           ...
# 4344                          NaN
# 4345                          NaN
# 4346                          NaN
# 4347                          NaN
# 4348                          NaN
#
#                                              Unnamed: 6     Unnamed: 7  \
# 0                                                   NaN            NaN
# 1                                                   NaN            NaN
# 2     ausländische Empfänger außerhalb von Einrichtu...   Altersgruppe
# 3                                                   NaN  unter 7 Jahre
# 4                                                Anzahl         Anzahl
# ...                                                 ...            ...
# 4344                                                NaN            NaN
# 4345                                                NaN            NaN
# 4346                                                NaN            NaN
# 4347                                                NaN            NaN
# 4348                                                NaN            NaN
#
#                 Unnamed: 8             Unnamed: 9            Unnamed: 10  \
# 0                      NaN                    NaN                    NaN
# 1                      NaN                    NaN                    NaN
# 2                      NaN                    NaN                    NaN
# 3     7 bis unter 18 Jahre  18 bis unter 25 Jahre  25 bis unter 50 Jahre
# 4                   Anzahl                 Anzahl                 Anzahl
# ...                    ...                    ...                    ...
# 4344                   NaN                    NaN                    NaN
# 4345                   NaN                    NaN                    NaN
# 4346                   NaN                    NaN                    NaN
# 4347                   NaN                    NaN                    NaN
# 4348                   NaN                    NaN                    NaN
#
#                 Unnamed: 11        Unnamed: 12
# 0                       NaN                NaN
# 1                       NaN                NaN
# 2                       NaN                NaN
# 3     50 bis unter 65 Jahre  65 Jahre und mehr
# 4                    Anzahl             Anzahl
# ...                     ...                ...
# 4344                    NaN                NaN
# 4345                    NaN                NaN
# 4346                    NaN                NaN
# 4347                    NaN                NaN
# 4348                    NaN                NaN
#
# [4349 rows x 13 columns]

# %%
data.iloc[1,:].tolist()[0]
# Out:
# 'Stichtag\nKreise und kreisfreie Städte'

# %%
data.iloc[2,:].tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  'weiblich',
#  'Ausländer(innen)',
#  'außerhalb von Einrichtungen',
#  'ausländische Empfänger außerhalb von Einrichtungen',
#  'Altersgruppe',
#  nan,
#  nan,
#  nan,
#  nan,
#  nan]

# %%
data.iloc[3,:].tolist()
# Out:
# [nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  'unter 7 Jahre',
#  '7 bis unter 18 Jahre',
#  '18 bis unter 25 Jahre',
#  '25 bis unter 50 Jahre',
#  '50 bis unter 65 Jahre',
#  '65 Jahre und mehr']

# %%
first_element=""
second_element=""
thirdd_element=""

entry=""
for i in range(len(data.iloc[1,:].tolist())):
    print("1: ",(str(data.iloc[1,:].tolist()[i]).replace("\n"," ")))

    if(data.iloc[1,:].tolist()[i]==data.iloc[1,:].tolist()[i-1]) or (data.iloc[1,:].tolist()[i]==np.nan):
        entry=firstelement+"_"+data.iloc[2,:].tolist()[i]
        print("triggered")
    else:
        firstelement=(str(data.iloc[1,:].tolist()[i]).replace("\n"," "))
        entry=firstelement
    print("2: ",data.iloc[2,:].tolist()[i])
    print("3: ",data.iloc[3,:].tolist()[i])
    print(entry)
# Out:
# 1:  Stichtag Kreise und kreisfreie Städte
# 2:  nan
# 3:  nan
# Stichtag Kreise und kreisfreie Städte
# 1:  nan
# 2:  nan
# 3:  nan
# nan
# 1:  Empfänger(innen) von Sozialhilfe
# 2:  nan
# 3:  nan
# Empfänger(innen) von Sozialhilfe
# 1:  Empfänger(innen) von Sozialhilfe
# triggered
# 2:  weiblich
# 3:  nan
# Empfänger(innen) von Sozialhilfe_weiblich
# 1:  nan
# 2:  Ausländer(innen)
# 3:  nan
# nan
# 1:  nan
# 2:  außerhalb von Einrichtungen
# 3:  nan
# nan
# 1:  nan
# 2:  ausländische Empfänger außerhalb von Einrichtungen
# 3:  nan
# nan
# 1:  nan
# 2:  Altersgruppe
# 3:  unter 7 Jahre
# nan
# 1:  nan
# 2:  nan
# 3:  7 bis unter 18 Jahre
# nan
# 1:  nan
# 2:  nan
# 3:  18 bis unter 25 Jahre
# nan
# 1:  nan
# 2:  nan
# 3:  25 bis unter 50 Jahre
# nan
# 1:  nan
# 2:  nan
# 3:  50 bis unter 65 Jahre
# nan
# 1:  nan
# 2:  nan
# 3:  65 Jahre und mehr
# nan

# %%
first_element=""
second_element=""
third_element=""

entry=""
for i in range(len(data.iloc[1,:].tolist())):
    print(i)
    if(pd.isnull(data.iloc[1,:].tolist()[i])):
        pass
    else:
        first_element=data.iloc[1,:].tolist()[i]
    if(pd.isnull(data.iloc[2,:].tolist()[i])):
        pass
    else:
        second_element=data.iloc[2,:].tolist()[i]
    if(pd.isnull(data.iloc[3,:].tolist()[i])):
        pass
    else:
        third_element=data.iloc[3,:].tolist()[i]
    print(first_element+"_"+second_element+"_"+third_element)
# Out:
# 0
# Stichtag
# Kreise und kreisfreie Städte__
# 1
# Stichtag
# Kreise und kreisfreie Städte__
# 2
# Empfänger(innen) von Sozialhilfe__
# 3
# Empfänger(innen) von Sozialhilfe_weiblich_
# 4
# Empfänger(innen) von Sozialhilfe_Ausländer(innen)_
# 5
# Empfänger(innen) von Sozialhilfe_außerhalb von Einrichtungen_
# 6
# Empfänger(innen) von Sozialhilfe_ausländische Empfänger außerhalb von Einrichtungen_
# 7
# Empfänger(innen) von Sozialhilfe_Altersgruppe_unter 7 Jahre
# 8
# Empfänger(innen) von Sozialhilfe_Altersgruppe_7 bis unter 18 Jahre
# 9
# Empfänger(innen) von Sozialhilfe_Altersgruppe_18 bis unter 25 Jahre
# 10
# Empfänger(innen) von Sozialhilfe_Altersgruppe_25 bis unter 50 Jahre
# 11
# Empfänger(innen) von Sozialhilfe_Altersgruppe_50 bis unter 65 Jahre
# 12
# Empfänger(innen) von Sozialhilfe_Altersgruppe_65 Jahre und mehr

# %%
datadropped=data.dropna(subset=[data.columns[0]])
indexlist=datadropped[datadropped[datadropped.columns[0]].str.startswith("31.12.")].index.tolist()
datadropped[datadropped[datadropped.columns[0]].str.startswith("31.12.")]
# Out:
#      Empfänger nach Geschlecht, Nationalität, Ort der\nLeistungserbringung, Altersgruppen - Stichtag 31.12. -\nregionale Tiefe: Kreise und krfr. Städte  \
# 5                                            31.12.2018
# 544                                          31.12.2017
# 1083                                         31.12.2016
# 1622                                         31.12.2015
# 2161                                         31.12.2014
# 2700                                         31.12.2013
# 3239                                         31.12.2012
# 3778                                         31.12.2011
#
#      Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6  \
# 5           NaN        NaN        NaN        NaN        NaN        NaN
# 544         NaN        NaN        NaN        NaN        NaN        NaN
# 1083        NaN        NaN        NaN        NaN        NaN        NaN
# 1622        NaN        NaN        NaN        NaN        NaN        NaN
# 2161        NaN        NaN        NaN        NaN        NaN        NaN
# 2700        NaN        NaN        NaN        NaN        NaN        NaN
# 3239        NaN        NaN        NaN        NaN        NaN        NaN
# 3778        NaN        NaN        NaN        NaN        NaN        NaN
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12
# 5           NaN        NaN        NaN         NaN         NaN         NaN
# 544         NaN        NaN        NaN         NaN         NaN         NaN
# 1083        NaN        NaN        NaN         NaN         NaN         NaN
# 1622        NaN        NaN        NaN         NaN         NaN         NaN
# 2161        NaN        NaN        NaN         NaN         NaN         NaN
# 2700        NaN        NaN        NaN         NaN         NaN         NaN
# 3239        NaN        NaN        NaN         NaN         NaN         NaN
# 3778        NaN        NaN        NaN         NaN         NaN         NaN

# %%
indexlist
# Out:
# [5, 544, 1083, 1622, 2161, 2700, 3239, 3778]

# %%
datadropped.loc[indexlist[0]:indexlist[1]]
# Out:
#     Empfänger nach Geschlecht, Nationalität, Ort der\nLeistungserbringung, Altersgruppen - Stichtag 31.12. -\nregionale Tiefe: Kreise und krfr. Städte  \
# 5                                           31.12.2018
# 6                                                   DG
# 7                                                   01
# 8                                                01001
# 9                                                01002
# ..                                                 ...
# 540                                              16074
# 541                                              16075
# 542                                              16076
# 543                                              16077
# 544                                         31.12.2017
#
#                                          Unnamed: 1 Unnamed: 2 Unnamed: 3  \
# 5                                               NaN        NaN        NaN
# 6                                       Deutschland     370159     167067
# 7                                Schleswig-Holstein      16782       7680
# 8                       Flensburg, Kreisfreie Stadt        643        312
# 9          Kiel, Landeshauptstadt, Kreisfreie Stadt       1309        625
# ..                                              ...        ...        ...
# 540                            Saale-Holzland-Kreis        185         72
# 541                                Saale-Orla-Kreis        334        146
# 542                                    Greiz, Kreis        311        122
# 543                         Altenburger Land, Kreis        235         99
# 544                                             NaN        NaN        NaN
#
#     Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  \
# 5          NaN        NaN        NaN        NaN        NaN        NaN
# 6        29779     121511      18568       8697      20850      19245
# 7          758       7060        607        311        752       1009
# 8           33        331         29          8         22         36
# 9          115        874        105         43         80         78
# ..         ...        ...        ...        ...        ...        ...
# 540          3         76          .          7         14          9
# 541          1         68          -         10         28         28
# 542          3        120          .          5         28         12
# 543          8        118          8         11         21         11
# 544        NaN        NaN        NaN        NaN        NaN        NaN
#
#     Unnamed: 10 Unnamed: 11 Unnamed: 12
# 5           NaN         NaN         NaN
# 6        118728      116912       85727
# 7          5910        5332        3468
# 8           219         219         139
# 9           512         397         199
# ..          ...         ...         ...
# 540          68          55          32
# 541         163          64          41
# 542          85         123          58
# 543          81          69          42
# 544         NaN         NaN         NaN
#
# [540 rows x 13 columns]
