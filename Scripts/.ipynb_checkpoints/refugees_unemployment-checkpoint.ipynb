# %%
import pandas as pd
import altair as alt
import geopandas as gpd

# %%
data=pd.read_csv("../CleanedData/allyears_unemployment_refugees_kreis.csv",dtype={"AGS":str})

# %%
data
# Out:
#                  Länder und Kreise_ Bestand Arbeitsuchende1)_  \
# 0            01001 Flensburg, Stadt                      8681
# 1      01002 Kiel, Landeshauptstadt                     22044
# 2          01003 Lübeck, Hansestadt                     18440
# 3           01004 Neumünster, Stadt                      6855
# 4                01051 Dithmarschen                      7686
# ...                             ...                       ...
# 19247     16073 Saalfeld-Rudolstadt                      6692
# 19248    16074 Saale-Holzland-Kreis                      4445
# 19249        16075 Saale-Orla-Kreis                      4391
# 19250                   16076 Greiz                      5645
# 19251        16077 Altenburger Land                      7359
#
#       Arbeitsuchende im Kontext von Fluchtmigration1)_absolut  \
# 0                                                   1175
# 1                                                   2922
# ...

# %%
data["Arbeitslose_ohne_Fluchtkontext"]=pd.to_numeric(data["Bestand Arbeitslose1)_"],errors="coerce")-pd.to_numeric(data["Arbeitslose im Kontext von Fluchtmigration1)_absolut"],errors="coerce")

# %%
for i in brandenburg["Länder und Kreise_"].unique():
    print(i)
    lk_data=brandenburg[brandenburg["Länder und Kreise_"]==i]
    lk_data=lk_data[["Länder und Kreise_","datum","Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"]]

    melted=pd.melt(lk_data, id_vars=["Länder und Kreise_","datum"],var_name="Kontext",value_name="Arbeitslose" ,value_vars=["Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"])
    melted
    melted["Arbeitslose"]=pd.to_numeric(melted["Arbeitslose"],errors="coerce")
    melted.sort_values("datum")
    chart=alt.Chart(melted).mark_line().encode(
    x='datum',
    y="Arbeitslose:Q",
    color="Kontext"
    )
    chart.display()
# Out:
# 12051 Brandenburg an der Havel, St.
# alt.Chart(...)
# 12052 Cottbus, Stadt
# alt.Chart(...)
# 12053 Frankfurt (Oder), Stadt
# alt.Chart(...)
# 12054 Potsdam, Stadt
# alt.Chart(...)
# 12060 Barnim
# alt.Chart(...)
# 12061 Dahme-Spreewald
# alt.Chart(...)
# 12062 Elbe-Elster
# alt.Chart(...)
# 12063 Havelland
# alt.Chart(...)
# 12064 Märkisch-Oderland
# alt.Chart(...)
# 12065 Oberhavel
# alt.Chart(...)
# 12066 Oberspreewald-Lausitz
# alt.Chart(...)
# 12067 Oder-Spree
# alt.Chart(...)
# 12068 Ostprignitz-Ruppin
# alt.Chart(...)
# 12069 Potsdam-Mittelmark
# alt.Chart(...)
# 12070 Prignitz
# alt.Chart(...)
# 12071 Spree-Neiße
# alt.Chart(...)
# 12072 Teltow-Fläming
# alt.Chart(...)
# 12073 Uckermark
# alt.Chart(...)

# %%
lk_data=lk_data[["Länder und Kreise_","datum","Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"]]
lk_data
# Out:
#       Länder und Kreise_       datum  \
# 342      12073 Uckermark  2020-06-01
# 743      12073 Uckermark  2020-05-01
# 1144     12073 Uckermark  2020-04-01
# 1545     12073 Uckermark  2020-03-01
# 1946     12073 Uckermark  2020-02-01
# 2347     12073 Uckermark  2020-01-01
# 2748     12073 Uckermark  2019-12-01
# 3149     12073 Uckermark  2019-11-01
# 3550     12073 Uckermark  2019-10-01
# 3951     12073 Uckermark  2019-09-01
# 4352     12073 Uckermark  2019-08-01
# 4753     12073 Uckermark  2019-07-01
# 5154     12073 Uckermark  2019-06-01
# 5555     12073 Uckermark  2019-05-01
# 5956     12073 Uckermark  2019-04-01
# 6357     12073 Uckermark  2019-03-01
# 6758     12073 Uckermark  2019-02-01
# 7159     12073 Uckermark  2019-01-01
# 7560     12073 Uckermark  2018-12-01
# 7961     12073 Uckermark  2018-11-01
# 8362     12073 Uckermark  2018-10-01
# 8763     12073 Uckermark  2018-09-01
# 9164     12073 Uckermark  2018-08-01
# 9565     12073 Uckermark  2018-07-01
# ...

# %%
lk_data=lk_data[["Länder und Kreise_","datum","Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"]]

melted=pd.melt(lk_data, id_vars=["Länder und Kreise_","datum"],var_name="Kontext",value_name="Arbeitslose" ,value_vars=["Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"])
melted
# Out:
#    Länder und Kreise_       datum  \
# 0     12073 Uckermark  2020-06-01
# 1     12073 Uckermark  2020-05-01
# 2     12073 Uckermark  2020-04-01
# 3     12073 Uckermark  2020-03-01
# 4     12073 Uckermark  2020-02-01
# ..                ...         ...
# 91    12073 Uckermark  2016-11-01
# 92    12073 Uckermark  2016-10-01
# 93    12073 Uckermark  2016-09-01
# 94    12073 Uckermark  2016-08-01
# 95    12073 Uckermark  2016-07-01
#
#                                               Kontext Arbeitslose
# 0   Arbeitslose im Kontext von Fluchtmigration1)_a...         321
# 1   Arbeitslose im Kontext von Fluchtmigration1)_a...         312
# 2   Arbeitslose im Kontext von Fluchtmigration1)_a...         316
# 3   Arbeitslose im Kontext von Fluchtmigration1)_a...         299
# 4   Arbeitslose im Kontext von Fluchtmigration1)_a...         289
# ..                                                ...         ...
# 91                     Arbeitslose_ohne_Fluchtkontext        7690
# ...

# %%
melted.sort_values("datum")
chart=alt.Chart(melted).mark_line().encode(
x='datum',
y="Arbeitslose:Q",
color="Kontext"
)
chart.display()
# Out:
# alt.Chart(...)

# %%
base = alt.Chart(lk_data).encode(
    alt.X('datum:N', axis=alt.Axis(title=None))
)
line = base.mark_line(stroke='#5276A7', interpolate='monotone').encode(
    alt.Y("Arbeitslose_ohne_Fluchtkontext")
)
line2 = base.mark_line(stroke='orange', interpolate='monotone').encode(
    alt.Y("Arbeitslose im Kontext von Fluchtmigration1)_absolut")
)

# %%
alt.layer(line2, line).resolve_scale(
    y = 'independent'
)
# Out:
# alt.LayerChart(...)

# %%
brandenburg=data[data["AGS"].str.startswith("12")]
brandenburg
# Out:
#                         Länder und Kreise_ Bestand Arbeitsuchende1)_  \
# 325    12051 Brandenburg an der Havel, St.                      5896
# 326                   12052 Cottbus, Stadt                      8057
# 327          12053 Frankfurt (Oder), Stadt                      4754
# 328                   12054 Potsdam, Stadt                     11027
# 329                           12060 Barnim                     10412
# ...                                    ...                       ...
# 19189             12069 Potsdam-Mittelmark                     10840
# 19190                       12070 Prignitz                      7248
# 19191                    12071 Spree-Neiße                      8045
# 19192                 12072 Teltow-Fläming                      9743
# 19193                      12073 Uckermark                     14769
#
#       Arbeitsuchende im Kontext von Fluchtmigration1)_absolut  \
# 325                                                  522
# ...

# %%
for i in brandenburg["Länder und Kreise_"].unique():
    print(i)
    lk_data=brandenburg[brandenburg["Länder und Kreise_"]==i]
    lk_data=lk_data[["Länder und Kreise_","datum","Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"]]

    melted=pd.melt(lk_data, id_vars=["Länder und Kreise_","datum"],var_name="Kontext",value_name="Arbeitslose" ,value_vars=["Arbeitslose im Kontext von Fluchtmigration1)_absolut","Arbeitslose_ohne_Fluchtkontext"])
    melted
    melted["Arbeitslose"]=pd.to_numeric(melted["Arbeitslose"],errors="coerce")
    melted.sort_values("datum")
    chart=alt.Chart(melted).mark_line().encode(
    x='datum',
    y="Arbeitslose:Q",
    color="Kontext"
    )
    chart.display()
# Out:
# 12051 Brandenburg an der Havel, St.
# alt.Chart(...)
# 12052 Cottbus, Stadt
# alt.Chart(...)
# 12053 Frankfurt (Oder), Stadt
# alt.Chart(...)
# 12054 Potsdam, Stadt
# alt.Chart(...)
# 12060 Barnim
# alt.Chart(...)
# 12061 Dahme-Spreewald
# alt.Chart(...)
# 12062 Elbe-Elster
# alt.Chart(...)
# 12063 Havelland
# alt.Chart(...)
# 12064 Märkisch-Oderland
# alt.Chart(...)
# 12065 Oberhavel
# alt.Chart(...)
# 12066 Oberspreewald-Lausitz
# alt.Chart(...)
# 12067 Oder-Spree
# alt.Chart(...)
# 12068 Ostprignitz-Ruppin
# alt.Chart(...)
# 12069 Potsdam-Mittelmark
# alt.Chart(...)
# 12070 Prignitz
# alt.Chart(...)
# 12071 Spree-Neiße
# alt.Chart(...)
# 12072 Teltow-Fläming
# alt.Chart(...)
# 12073 Uckermark
# alt.Chart(...)

# %%
for i in brandenburg["Länder und Kreise_"].unique():
    print(i)
    lk_data=brandenburg[brandenburg["Länder und Kreise_"]==i]
    chart=alt.Chart(lk_data).mark_line().encode(
    x='datum:N',
    y="Arbeitslose im Kontext von Fluchtmigration1)_Anteil an Sp. 7 in %:Q",
    )
    chart.display()
# Out:
# 12051 Brandenburg an der Havel, St.
# alt.Chart(...)
# 12052 Cottbus, Stadt
# alt.Chart(...)
# 12053 Frankfurt (Oder), Stadt
# alt.Chart(...)
# 12054 Potsdam, Stadt
# alt.Chart(...)
# 12060 Barnim
# alt.Chart(...)
# 12061 Dahme-Spreewald
# alt.Chart(...)
# 12062 Elbe-Elster
# alt.Chart(...)
# 12063 Havelland
# alt.Chart(...)
# 12064 Märkisch-Oderland
# alt.Chart(...)
# 12065 Oberhavel
# alt.Chart(...)
# 12066 Oberspreewald-Lausitz
# alt.Chart(...)
# 12067 Oder-Spree
# alt.Chart(...)
# 12068 Ostprignitz-Ruppin
# alt.Chart(...)
# 12069 Potsdam-Mittelmark
# alt.Chart(...)
# 12070 Prignitz
# alt.Chart(...)
# 12071 Spree-Neiße
# alt.Chart(...)
# 12072 Teltow-Fläming
# alt.Chart(...)
# 12073 Uckermark
# alt.Chart(...)

# %%
brandenburg
# Out:
#                         Länder und Kreise_ Bestand Arbeitsuchende1)_  \
# 325    12051 Brandenburg an der Havel, St.                      5896
# 326                   12052 Cottbus, Stadt                      8057
# 327          12053 Frankfurt (Oder), Stadt                      4754
# 328                   12054 Potsdam, Stadt                     11027
# 329                           12060 Barnim                     10412
# ...                                    ...                       ...
# 19189             12069 Potsdam-Mittelmark                     10840
# 19190                       12070 Prignitz                      7248
# 19191                    12071 Spree-Neiße                      8045
# 19192                 12072 Teltow-Fläming                      9743
# 19193                      12073 Uckermark                     14769
#
#       Arbeitsuchende im Kontext von Fluchtmigration1)_absolut  \
# 325                                                  522
# ...
